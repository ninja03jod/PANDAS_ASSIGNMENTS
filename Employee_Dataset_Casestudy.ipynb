# %% [markdown]
# <a href="https://colab.research.google.com/github/ninja03jod/PANDAS_ASSIGNMENTS/blob/main/Employee_Dataset_Casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Salaries.csv")
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# we can get the dtype of each column and their total entries values are null or non null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
# lets change the jobTitle dtype to category
# category is also dtype
# difference between category dtype and object :
# - category dtye consume less memory than object dtype
# in above info memroy consumed is about 14.7 mb

df.JobTitle = df.JobTitle.astype("category")

# %%
df.info()
# dtype is changed and memory consumed is less so file uplodin will easy due to less memory
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  category
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: category(1), float64(8), int64(2), object(2)
# memory usage: 14.0+ MB

# %%
df.JobTitle.astype("category") # this will gives only category under job title column
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: category
# Categories (2159, object): ['ACCOUNT CLERK', 'ACCOUNTANT', 'ACCOUNTANT INTERN',
#                             'ACPO,JuvP, Juv Prob (SFERS)', ..., 'X-Ray Laboratory Aide',
#                             'YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS', 'Youth Comm Advisor', 'ZOO CURATOR']

# %%
# lets reduce bit size
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  category
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: category(1), float64(8), int64(2), object(2)
# memory usage: 14.0+ MB

# %%
# lets reduce bitsize of Total pay column
df.TotalPay = df.TotalPay.astype("float32")
# float 16 will be helpful for values if they are in less number of availability
# here are records of category in lakhs so we can reduce but size little bit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  category
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float32
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: category(1), float32(1), float64(7), int64(2), object(2)
# memory usage: 13.4+ MB

# %%
# check the head of dataframe:
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN       inf         567595.43
# 1  155966.02    245131.88  137811.38       NaN       inf         538909.28
# 2  212739.13    106088.18   16452.60       NaN       inf         335279.91
# 3   77916.00     56120.71  198306.90       NaN       inf         332343.61
# 4  134401.60      9737.00  182234.59       NaN       inf         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
# check the nan values
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
# Check the record of rows and columns
print("Number of rows are:",df.shape[0])
print("Number of columns are:",df.shape[1])
# Out:
# Number of rows are: 148654
# Number of columns are: 13

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
# drop Notes ,'Agency' and Status columns bcz they have 100% missing values
df.drop(columns=["Notes","Agency","Status"],inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# check new shape:
print(df.shape[0])
print(df.shape[1])
# Out:
# 148654
# 10

# %%
# check how many null values are avail
df.isna().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               609
# OvertimePay             4
# OtherPay                4
# Benefits            36163
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
df.describe()
# here we can see payment should not be less than 0
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4527: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits  TotalPay  TotalPayBenefits           Year
# count  112491.000000  148654.0     148654.000000  148654.000000
# mean    25007.893151       inf      93692.554811    2012.522643
# ...

# %%
# fill BasePay NaN by using some technique
# there are 609 nan entries in BasePay
df.BasePay.fillna(66325.44) # lets take an average of basepay
# nan values are cahnged
# this value changed are temporary
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650     66325.44
# 148651     66325.44
# 148652     66325.44
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
# let change nan value permanantly
df.BasePay = df.BasePay.fillna(66325.44)

# %%
# lets see how many nan value are in basepay
df.BasePay.isna().sum()
# Out:
# 0

# %%
df.BasePay.plot(kind="box")
# Out:
# <Axes: >

# %%
# check BasePay of Transit Operator
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# Transit operator category present in JobTitle column so we have to fetch basepay of transit operator
df.groupby("JobTitle").get_group("Transit Operator")
# Out:
#             Id     EmployeeName          JobTitle   BasePay  OvertimePay  \
# 38624    38625      Duane Allen  Transit Operator  69212.89     75242.51
# 39387    39388    Nancy Padilla  Transit Operator  69872.39     69054.76
# 39575    39576    Louis Galarce  Transit Operator  69743.96     65581.66
# 39738    39739     Freeman Chee  Transit Operator  70892.56     61682.94
# 39904    39905  Robert Dufresne  Transit Operator  71251.23     56238.12
# ...        ...              ...               ...       ...          ...
# 148211  148212   Brelyn S Moody  Transit Operator    340.62       113.54
# 148225  148226  Erris C Edgerly  Transit Operator      0.00         0.00
# 148398  148399   Shane O'Connor  Transit Operator    151.38        56.77
# 148463  148464      William Tam  Transit Operator    148.78         0.00
# 148621  148622   Kenneth Mackey  Transit Operator      0.00         0.00
#
#         OtherPay  Benefits    TotalPay  TotalPayBenefits  Year
# ...

# %%
# we can fetch it thorugh query
df.query("JobTitle=='Transit Operator'")
# Out:
#             Id     EmployeeName          JobTitle   BasePay  OvertimePay  \
# 38624    38625      Duane Allen  Transit Operator  69212.89     75242.51
# 39387    39388    Nancy Padilla  Transit Operator  69872.39     69054.76
# 39575    39576    Louis Galarce  Transit Operator  69743.96     65581.66
# 39738    39739     Freeman Chee  Transit Operator  70892.56     61682.94
# 39904    39905  Robert Dufresne  Transit Operator  71251.23     56238.12
# ...        ...              ...               ...       ...          ...
# 148211  148212   Brelyn S Moody  Transit Operator    340.62       113.54
# 148225  148226  Erris C Edgerly  Transit Operator      0.00         0.00
# 148398  148399   Shane O'Connor  Transit Operator    151.38        56.77
# 148463  148464      William Tam  Transit Operator    148.78         0.00
# 148621  148622   Kenneth Mackey  Transit Operator      0.00         0.00
#
#         OtherPay  Benefits    TotalPay  TotalPayBenefits  Year
# ...

# %%
df.JobTitle == "Transit Operator"
# This will gives only boolean output
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
# for getting the Transit operator category use []
df[df.JobTitle == "Transit Operator"]
# Out:
#             Id     EmployeeName          JobTitle   BasePay  OvertimePay  \
# 38624    38625      Duane Allen  Transit Operator  69212.89     75242.51
# 39387    39388    Nancy Padilla  Transit Operator  69872.39     69054.76
# 39575    39576    Louis Galarce  Transit Operator  69743.96     65581.66
# 39738    39739     Freeman Chee  Transit Operator  70892.56     61682.94
# 39904    39905  Robert Dufresne  Transit Operator  71251.23     56238.12
# ...        ...              ...               ...       ...          ...
# 148211  148212   Brelyn S Moody  Transit Operator    340.62       113.54
# 148225  148226  Erris C Edgerly  Transit Operator      0.00         0.00
# 148398  148399   Shane O'Connor  Transit Operator    151.38        56.77
# 148463  148464      William Tam  Transit Operator    148.78         0.00
# 148621  148622   Kenneth Mackey  Transit Operator      0.00         0.00
#
#         OtherPay  Benefits    TotalPay  TotalPayBenefits  Year
# ...

# %%
# lets fetch average of total payment for each job
df.groupby("JobTitle")["TotalPay"].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     4.404012e+04
# ACCOUNTANT                                        4.742960e+04
# ACCOUNTANT INTERN                                 2.903079e+04
# ACPO,JuvP, Juv Prob (SFERS)                       6.230400e+04
# ACUPUNCTURIST                                              inf
#                                                       ...
# X-RAY LABORATORY AIDE                                      NaN
# X-Ray Laboratory Aide                                      NaN
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    5.363200e+04
# Youth Comm Advisor                                4.142000e+04
# ZOO CURATOR                                                inf
# Name: TotalPay, Length: 2159, dtype: float32

# %%
# check duplicate rows
df.duplicated()
# this will gives boolean output for false: means not avail
# for True : means duplicate rows are avail
# To get direct ouput means if we use [] then it gives dupliacte rows if avail either not
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Length: 148654, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %% [markdown]
# ## we dont have any duplicate row

# %%
# we can check nan value for each column
df.isna().any()
# gives boolean output for nan
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# BasePay             False
# OvertimePay          True
# OtherPay             True
# Benefits             True
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# dtype: bool

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# No. records present in 2014
df[df.Year == 2014]
# Out:
#             Id          EmployeeName                    JobTitle    BasePay  \
# 110531  110532           David Shinn              Deputy Chief 3  129150.01
# 110532  110533            Amy P Hart           Asst Med Examiner  318835.49
# 110533  110534  William J Coaker Jr.    Chief Investment Officer  257340.00
# 110534  110535        Gregory P Suhr             Chief of Police  307450.04
# 110535  110536  Joanne M Hayes-White      Chief, Fire Department  302068.00
# ...        ...                   ...                         ...        ...
# 148649  148650         Roy I Tillery                   Custodian       0.00
# 148650  148651          Not provided                Not provided   66325.44
# 148651  148652          Not provided                Not provided   66325.44
# 148652  148653          Not provided                Not provided   66325.44
# 148653  148654             Joe Lopez  Counselor, Log Cabin Ranch       0.00
#
# ...

# %%
# we can use query method and also groupby method
df.query("Year == 2014")
# Out:
#             Id          EmployeeName                    JobTitle    BasePay  \
# 110531  110532           David Shinn              Deputy Chief 3  129150.01
# 110532  110533            Amy P Hart           Asst Med Examiner  318835.49
# 110533  110534  William J Coaker Jr.    Chief Investment Officer  257340.00
# 110534  110535        Gregory P Suhr             Chief of Police  307450.04
# 110535  110536  Joanne M Hayes-White      Chief, Fire Department  302068.00
# ...        ...                   ...                         ...        ...
# 148649  148650         Roy I Tillery                   Custodian       0.00
# 148650  148651          Not provided                Not provided   66325.44
# 148651  148652          Not provided                Not provided   66325.44
# 148652  148653          Not provided                Not provided   66325.44
# 148653  148654             Joe Lopez  Counselor, Log Cabin Ranch       0.00
#
# ...

# %%
# lets check integrity of data
df.query("Year == 2014")['BasePay'].plot(kind="box")
# Out:
# <Axes: >

# %%
df[df.Year == 2014]["BasePay"].plot(kind="hist",bins=[0,50000,100000,150000,200000,300000])
# Out:
# <Axes: ylabel='Frequency'>

# %%
# How many employee getting <=0 total Pay
sum(df.TotalPay <=0)
# Out:
# 369

# %%
df[["TotalPay"]].value_counts() # 368 employees with zero total payment
# Out:
# TotalPay
#  inf        82491
#  0.0          368
#  60352.0      126
#  53536.0      122
#  60736.0      122
#             ...
#  700.5          1
#  701.0          1
#  701.5          1
#  703.0          1
# -618.0          1
# Length: 7774, dtype: int64

# %%
# show the employee name who are getting 0 payment

df[df.TotalPay == 0]["EmployeeName"]
# Out:
# 36156         PAULETTE ADAMS
# 36157          KAUKAB MOHSIN
# 36158     JOSEPHINE MCCREARY
# 70877          Roland Baylon
# 70927       Felecia Phillips
#                  ...
# 148648           Leon Walker
# 148649         Roy I Tillery
# 148650          Not provided
# 148651          Not provided
# 148652          Not provided
# Name: EmployeeName, Length: 368, dtype: object

# %%
# display records of employee getting TotalPay <=0
df[df.TotalPay <= 0]
# Out:
#             Id        EmployeeName  \
# 36156    36157      PAULETTE ADAMS
# 36157    36158       KAUKAB MOHSIN
# 36158    36159  JOSEPHINE MCCREARY
# 70877    70878       Roland Baylon
# 70927    70928    Felecia Phillips
# ...        ...                 ...
# 148649  148650       Roy I Tillery
# 148650  148651        Not provided
# 148651  148652        Not provided
# 148652  148653        Not provided
# 148653  148654           Joe Lopez
#
#                                           JobTitle   BasePay  OvertimePay  \
# 36156   STATIONARY ENGINEER, WATER TREATMENT PLANT      0.00          0.0
# 36157                             TRANSIT OPERATOR      0.00          0.0
# 36158                                   MANAGER IV      0.00          0.0
# 70877                        Deputy Court Clerk II      0.00          0.0
# 70927                             Registered Nurse      0.00          0.0
# ...                                            ...       ...          ...
# ...

# %%
# Display the employee name who has less than 0 payment
df[df.TotalPay <0][['EmployeeName']]
# Out:
#        EmployeeName
# 148653    Joe Lopez

# %%
# lets cross check
df.groupby("EmployeeName").get_group("Joe Lopez")
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year
# 148653   -618.13       0.0    -618.0           -618.13  2014

# %%
# how many are there whose post is Not provided
df.query("JobTitle == 'Not provided'")
# Out:
#             Id  EmployeeName      JobTitle   BasePay  OvertimePay  OtherPay  \
# 148646  148647  Not provided  Not provided  66325.44          NaN       NaN
# 148650  148651  Not provided  Not provided  66325.44          NaN       NaN
# 148651  148652  Not provided  Not provided  66325.44          NaN       NaN
# 148652  148653  Not provided  Not provided  66325.44          NaN       NaN
#
#         Benefits  TotalPay  TotalPayBenefits  Year
# 148646       NaN       0.0               0.0  2014
# 148650       NaN       0.0               0.0  2014
# 148651       NaN       0.0               0.0  2014
# 148652       NaN       0.0               0.0  2014

# %%
# what is avergae BasePay?
df[["BasePay"]].mean()
# Out:
# BasePay    66325.448804
# dtype: float64

# %%
# what is highest amount of OvertimePay in data set
df.OvertimePay.max()
# Out:
# 245131.88

# %%
# fetch record of highest paid employee
df[df.TotalPayBenefits==df.TotalPayBenefits.max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN       inf         567595.43
#
#    Year
# 0  2011

# %%
#Fetch name of highest Overtime pay employee
#df.query('OvertimePay==OvertimePay.max()')['EmployeeName']
df.query('OvertimePay==OvertimePay.max()').EmployeeName
# Out:
# 1    GARY JIMENEZ
# Name: EmployeeName, dtype: object

# %% [markdown]
# ##What is the job title of JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).

# %%
df[df.EmployeeName == 'JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 24  31909.28       NaN  270324.91         270324.91  2011

# %%
df.query("EmployeeName == 'JOSEPH DRISCOLL'")
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 24  31909.28       NaN  270324.91         270324.91  2011

# %%
# fetch both jospeh driscoll upper and lower case records
df[df['EmployeeName'].str.contains('joseph driscoll',case=False)]
# Out:
#           Id     EmployeeName                   JobTitle    BasePay  \
# 24        25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86
# 36198  36199  Joseph Driscoll  Captain, Fire Suppression  145658.98
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 24        97868.77  31909.28       NaN  270324.91         270324.91  2011
# 36198    114513.29  28743.36  42919.16  288915.63         331834.79  2012

# %%
# Yearwise average TotalPay
df.groupby("Year")[["TotalPay"]].mean()
# Out:
#           TotalPay
# Year
# 2011  71744.103871
# 2012  74113.262265
# 2013  77611.443142
# 2014  75463.918140

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# How much does JOSEPH DRISCOLL make (including benefits)
df[df.EmployeeName== 'JOSEPH DRISCOLL'][["TotalPayBenefits"]]
# Out:
#     TotalPayBenefits
# 24         270324.91

# %%
df.groupby("EmployeeName").get_group("JOSEPH DRISCOLL")[['TotalPayBenefits']]
# Out:
#     TotalPayBenefits
# 24         270324.91

# %%
df.query('EmployeeName=="JOSEPH DRISCOLL"').TotalPayBenefits
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
df[:5]
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
# I want mean, sum, std of TotalPay	TotalPayBenefits
df[["TotalPay","TotalPayBenefits"]].agg([np.sum,np.mean,np.std])
# Out:
#           TotalPay  TotalPayBenefits
# sum   1.111461e+10      1.392777e+10
# mean  7.476832e+04      9.369255e+04
# std   5.051701e+04      6.279353e+04

# %%
# Create a new feature Bonus : condition is=Add 20% of BasePay into TotalPay
df['Bonus'] = df.BasePay*0.2 + df.TotalPay

# %%
df["Bonus"]
# Out:
# 0         601077.666
# 1         570102.484
# 2         377827.736
# 3         347926.810
# 4         353253.510
#              ...
# 148649         0.000
# 148650           NaN
# 148651           NaN
# 148652           NaN
# 148653      -618.130
# Name: Bonus, Length: 148654, dtype: float64

# %%
df[["JobTitle"]]
# Out:
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# 148651                                    Not provided
# 148652                                    Not provided
# 148653                      Counselor, Log Cabin Ranch
#
# [148654 rows x 1 columns]

# %%
# Fetch CAPTAIN III (POLICE DEPARTMENT) whose TotalPay is> 400000
df.query("JobTitle=='CAPTAIN III (POLICE DEPARTMENT)' and TotalPay> 400000")
# Out:
#    Id  EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 1   2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year       Bonus
# 1  137811.38       NaN  538909.28         538909.28  2011  570102.484

# %%
df[df.JobTitle == 'CAPTAIN III (POLICE DEPARTMENT)'][df.TotalPay> 400000]
# Out:
# <ipython-input-22-72dfbc0a9ac7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.JobTitle == 'CAPTAIN III (POLICE DEPARTMENT)'][df.TotalPay> 400000]
#    Id  EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 1   2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year       Bonus
# 1  137811.38       NaN  538909.28         538909.28  2011  570102.484

# %%
# yearwise sum of BasePay and average basePay
df.groupby("Year")[["BasePay"]].agg([np.sum,np.mean])
# Out:
#            BasePay
#                sum          mean
# Year
# 2011  2.299566e+09  63595.956517
# 2012  2.405835e+09  65436.406857
# 2013  2.576381e+09  69630.030216
# 2014  2.537369e+09  66564.421924

# %%
# What is the name, Job title of highest paid person (including benefits)

df.query('TotalPayBenefits==TotalPayBenefits.max()')[['EmployeeName','JobTitle']]
# Out:
#      EmployeeName                                        JobTitle
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY

# %%
# What is the name, Job title of highest paid person (including benefits)
df[df.TotalPayBenefits == df.TotalPayBenefits.max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year       Bonus
# 0  2011  601077.666

# %%
# What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?
df.query("TotalPayBenefits==TotalPayBenefits.min()")[["EmployeeName","TotalPayBenefits"]]
# Out:
#        EmployeeName  TotalPayBenefits
# 148653    Joe Lopez           -618.13

# %%
# What was the average (mean) BasePay of all employees per year? (2011-2014)
df.groupby("Year")[["BasePay"]].mean()
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
# How many unique job titles are there
df[["JobTitle"]].nunique()
# Out:
# JobTitle    2159
# dtype: int64

# %%
# What are the top 5 most common jobs

df[["JobTitle"]].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# dtype: int64

# %%
# fetch the first record of each job
df.groupby("JobTitle").first()
# Out:
#                                                     Id           EmployeeName  \
# JobTitle
# ACCOUNT CLERK                                    20766         NAPOLEON VIRAY
# ACCOUNTANT                                       19264       CARLITO NEPACENA
# ACCOUNTANT INTERN                                21536             PENG HUANG
# ACPO,JuvP, Juv Prob (SFERS)                     135284  Palminder K Hernandez
# ACUPUNCTURIST                                    18379                 WEN XU
# ...                                                ...                    ...
# X-RAY LABORATORY AIDE                            12940            DELBERT LEE
# X-Ray Laboratory Aide                            49777            Delbert Lee
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   23392          MARIO YEDIDIA
# Youth Comm Advisor                               58843          Mario Yedidia
# ZOO CURATOR                                      18779            MYRON SULAK
#
# ...

# %%
# How many are there those work as a POLICE OFFICER III

df[df.JobTitle == 'POLICE OFFICER III'].shape[0]
# Out:
# 779

# %%
# Show the records of those work as a POLICE OFFICER III
df.query("JobTitle== 'POLICE OFFICER III'")
# Out:
#           Id        EmployeeName            JobTitle    BasePay  OvertimePay  \
# 111      112       C PETRUZZELLA  POLICE OFFICER III   63811.18     57966.33
# 244      245     MICHAEL SIMMONS  POLICE OFFICER III  112441.80     17715.27
# 263      264      THOMAS CUNNANE  POLICE OFFICER III  112421.46     14978.42
# 271      272     DENNIS MARTINEZ  POLICE OFFICER III  112401.06     45977.26
# 302      303      EDGAR GONZALEZ  POLICE OFFICER III  112441.79     15338.11
# ...      ...                 ...                 ...        ...          ...
# 30779  30780  CONSTANTINE ZACHOS  POLICE OFFICER III   12384.70         0.00
# 32719  32720          JOHN TURSI  POLICE OFFICER III    6781.25         0.00
# 33307  33308      GERALD SCHMIDT  POLICE OFFICER III    5014.40         0.00
# 35318  35319      ROBERT CHAPMAN  POLICE OFFICER III       0.00         0.00
# 35671  35672       RUSSELL MATLI  POLICE OFFICER III       0.00         0.00
#
# ...

# %%
# In which department we have least employees
df[["JobTitle"]].min()
# Out:
# JobTitle    ACCOUNT CLERK
# dtype: object

# %%
# lets cross check
df.groupby("JobTitle").get_group("ACCOUNT CLERK")
# Out:
#           Id      EmployeeName       JobTitle   BasePay  OvertimePay  \
# 20765  20766    NAPOLEON VIRAY  ACCOUNT CLERK  60838.20         0.00
# 20867  20868  BERNADETTE RAMOS  ACCOUNT CLERK  49777.81     10753.06
# 21638  21639       SUSAN CHANG  ACCOUNT CLERK  51306.28      5406.34
# 22972  22973  OLIVIA BOUDREAUX  ACCOUNT CLERK  49778.15      3811.68
# 24132  24133        LI-XIN CAI  ACCOUNT CLERK  49777.80      1390.45
# ...      ...               ...            ...       ...          ...
# 31245  31246     ALISHA WILLIS  ACCOUNT CLERK  11247.02         0.00
# 32035  32036    BARBARA BLOUNT  ACCOUNT CLERK   8681.58        69.82
# 34974  34975          LIEN LUM  ACCOUNT CLERK   1630.00         0.00
# 34975  34976        RACHEL LAU  ACCOUNT CLERK   1630.00         0.00
# 35637  35638     TSE SHIH LENG  ACCOUNT CLERK    614.00         0.00
#
#        OtherPay  Benefits  TotalPay  TotalPayBenefits  Year      Bonus
# ...

# %%
# Fetch record of year 2011 where Basepay 200000
df[df.Year == 2011][df.BasePay==200000]
# Out:
# <ipython-input-81-22d278230f59>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.Year == 2011][df.BasePay==200000]
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Bonus]
# Index: []

# %%
# How much average basepay is given to employees inthe year 2013
df[df.Year == 2013]['BasePay'].mean()
# Out:
# 69630.03021648065

# %%
df.query("Year == 2013").BasePay.mean()
# Out:
# 69630.03021648065

# %%
# Plot the % distribustion of Yearwise TotalPay

df.groupby("Year")[["TotalPay"]].sum().plot(kind="pie",y="TotalPay",autopct="%2.f%%")
# Out:
# <Axes: ylabel='TotalPay'>

# %%
# Plot the % distribustion of Yearwise TotalPay
df.groupby("Year")[["TotalPay"]].sum().plot(kind="pie",y = "TotalPay",autopct="%2.f%%")
# Out:
# <Axes: ylabel='TotalPay'>

# %%
df[:2]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
#
#    Year       Bonus
# 0  2011  601077.666
# 1  2011  570102.484

# %%
# How many employees getting 0 overtimePay?
df[df.OvertimePay==0].shape[0]
# Out:
# 77321
